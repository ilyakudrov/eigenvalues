# %%
import numpy as np
import pandas as pd
import struct
import math
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import seaborn as sns
sns.set_style('darkgrid')
import sys

# %%
def eigen_module(re, im):
    return math.sqrt(re*re + im*im)

# %%
def eigen_hist(arr, N):
    arr1 = np.array(arr)
    max = np.amax(arr1)
    delta = max/N
    arr_hist = []
    arr_x = []
    for i in range(N):
        count = 0
        for j in range(arr1.size):
            if (arr1[j] > i*delta and arr1[j] <= (i+1)*delta):
                count+=1
        arr_hist.append(count/math.pi/(((i+1)*delta)**2 - (i*delta)**2)/arr1.size)
        arr_x.append(i*delta)
    plt.plot(arr_x, arr_hist, 'o')
    plt.show()
    plt.clf()

# %%
def eigen_hist_nonorm(arr, N):
    arr1 = np.array(arr)
    max = np.amax(arr1)
    delta = max/N
    arr_hist = []
    arr_x = []
    for i in range(N):
        count = 0
        for j in range(arr1.size):
            if (arr1[j] > i*delta and arr1[j] <= (i+1)*delta):
                count+=1
        arr_hist.append(count)
        arr_x.append(i*delta)
    plt.plot(arr_x, arr_hist, 'o')
    plt.show()
    plt.clf()

# %%
def complex_plane(arr):

# %%
path='../../results/final/eigenvalues.csv'
df=pd.read_csv(path)

# %%
def find_module(data, res):
    arr_module = []
    for index, row in data.iterrows():
        arr_module.append(eigen_module(row['re'], row['im']))
    res.append(arr_module)
    #return data

# %%
res = []
df.groupby('mu').apply(find_module, res)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(len(res)):
    eigen_hist(res[i], 10)

# %%
for i in range(len(res)):
    eigen_hist_nonorm(res[i], 10)

# %%
def find_complex(data, res_re, res_im):
    arr_re = []
    arr_im = []
    for index, row in data.iterrows():
        arr_re.append(row['re'])
        arr_im.append(row['im'])
    res_re.append(arr_re)
    res_im.append(arr_im)

# %%
res_re = []
res_im = []
df.groupby('mu').apply(find_complex, res_re, res_im)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(len(res_re)):
    plt.scatter(res_re[i], res_im[i], color='red', s = 0.2)
    plt.show()
    plt.clf()
